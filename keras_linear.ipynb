# %% [markdown]
# <a href="https://colab.research.google.com/github/Vignesh-Desmond/DL-CV-2020/blob/master/keras_linear.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow.keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
n_pts = 500
np.random.seed(3)
Xa = np.array([np.random.normal(13, 2, n_pts),
              np.random.normal(12, 2, n_pts)]).T
Xb = np.array([np.random.normal(8, 2, n_pts),
              np.random.normal(6, 2, n_pts)]).T
     
X = np.vstack((Xa, Xb))
y = np.matrix(np.append(np.zeros(n_pts), np.ones(n_pts))).T
     
plt.scatter(X[:n_pts,0], X[:n_pts,1])
plt.scatter(X[n_pts:,0], X[n_pts:,1])

# %%
model = Sequential()
model.add(Dense(units= 1, input_shape = (2,), activation='sigmoid'))
adam = Adam(learning_rate= 0.1)
model.compile(adam, loss = 'binary_crossentropy', metrics = ['accuracy'])
hmodel.fit(x=X, y=y, verbose = 1, batch_size = 20, epochs = 100)
# Out:
# Epoch 1/100
# 50/50 [==============================] - 0s 759us/step - loss: 1.2990 - accuracy: 0.5150
# Epoch 2/100
# 50/50 [==============================] - 0s 770us/step - loss: 0.3717 - accuracy: 0.8890
# Epoch 3/100
# 50/50 [==============================] - 0s 799us/step - loss: 0.2805 - accuracy: 0.9460
# Epoch 4/100
# 50/50 [==============================] - 0s 745us/step - loss: 0.2279 - accuracy: 0.9540
# Epoch 5/100
# 50/50 [==============================] - 0s 735us/step - loss: 0.1971 - accuracy: 0.9610
# Epoch 6/100
# 50/50 [==============================] - 0s 842us/step - loss: 0.1685 - accuracy: 0.9650
# Epoch 7/100
# 50/50 [==============================] - 0s 803us/step - loss: 0.1597 - accuracy: 0.9670
# Epoch 8/100
# 50/50 [==============================] - 0s 762us/step - loss: 0.1445 - accuracy: 0.9660
# Epoch 9/100
# 50/50 [==============================] - 0s 761us/step - loss: 0.1317 - accuracy: 0.9700
# Epoch 10/100
# ...

# %%
plt.plot(h.history['loss'])
plt.xlabel('epochs')
plt.title('loss')
# Out:
# Text(0.5, 1.0, 'loss')

# %%
def plot_decision_boundary(x, y, model):
  x_span = np.linspace(min(x[:,0]) - 1, max(x[:,0]) + 1)
  y_span = np.linspace(min(x[:,1]) - 1, max(x[:,1]) + 1)
  xx, yy = np.meshgrid(x_span, y_span)
  xx_, yy_ = xx.ravel(), yy.ravel()
  grid = np.c_[xx_, yy_]
  pred_func = model.predict(grid)
  z = pred_func.reshape(xx.shape)
  plt.contourf(xx, yy, z)

# %%
plot_decision_boundary(X, y, model)
plt.scatter(X[:n_pts,0], X[:n_pts,1])
plt.scatter(X[n_pts:,0], X[n_pts:,1])

# %%
    plot_decision_boundary(X, y, model)
    plt.scatter(X[:n_pts,0], X[:n_pts,1])
    plt.scatter(X[n_pts:,0], X[n_pts:,1])
    x = 9
    y = 11.5   
    point = np.array([[x, y]])
    prediction = model.predict(point)
    plt.plot([x], [y], marker='o', markersize=10, color="red")
    plt.title("Prediction value: " + str(prediction[0][0]))
# Out:
# Text(0.5, 1.0, 'Prediction value: 0.0064773858')
